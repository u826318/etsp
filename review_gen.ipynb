# %%
# !pip install emoji
# !pip install langdetect
# Out:
# Requirement already satisfied: emoji in /usr/local/lib/python3.12/dist-packages (2.15.0)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.12/dist-packages (1.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from langdetect) (1.17.0)

# %%
import os
import json
import random
import time
import re
import shutil
import gzip
import urllib.request
from pathlib import Path
from typing import Dict, List, Optional
from collections import defaultdict
from openai import OpenAI
from tqdm.auto import tqdm


API_KEY = "sk-xxxxxxxxxxxxxxxxxxx"
BASE_URL = "https://dashscope.aliyuncs.com/compatible-mode/v1"
MODEL_NAME = "qwen-plus"

SAMPLES_PER_CATEGORY = 200
MIN_REVIEWS_PER_PRODUCT = 5
MAX_REVIEWS_INPUT = 30

try:
    from google.colab import drive
    drive.mount('/content/drive')
    BASE_DIR = Path("/content/drive/MyDrive/ETSP")
except ImportError:
    BASE_DIR = Path("ETSP")

REVIEW_BASE_URL = "https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/review_categories/"
META_BASE_URL = "https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/meta_categories/"

client = OpenAI(api_key=API_KEY, base_url=BASE_URL)


def download_file(url: str, output_path: str) -> bool:
    """Download file from URL."""
    try:
        print(f"Downloading {Path(output_path).name}...")
        urllib.request.urlretrieve(url, output_path)
        return True
    except Exception as e:
        print(f"Download failed: {e}")
        return False

def decompress_gz(gz_path: str) -> Optional[str]:
    """Decompress .gz file and remove archive."""
    output_path = gz_path[:-3]
    try:
        print(f"Decompressing {Path(gz_path).name}...")
        with gzip.open(gz_path, 'rb') as f_in:
            with open(output_path, 'wb') as f_out:
                shutil.copyfileobj(f_in, f_out)
        os.remove(gz_path)
        return output_path
    except Exception as e:
        print(f"Decompression failed: {e}")
        return None

def ensure_data_files(category: str) -> tuple:
    """Ensure review/meta files exist via move or download."""
    category_dir = BASE_DIR / category
    category_dir.mkdir(parents=True, exist_ok=True)
    target_reviews = category_dir / f"{category}.jsonl"
    target_meta = category_dir / f"meta_{category}.jsonl"

    # Reviews
    if not target_reviews.exists():
        root_review = BASE_DIR / f"{category}.jsonl"
        if root_review.exists():
            shutil.move(str(root_review), str(target_reviews))
        else:
            gz_path = category_dir / f"{category}.jsonl.gz"
            if download_file(f"{REVIEW_BASE_URL}{category}.jsonl.gz", str(gz_path)):
                decompress_gz(str(gz_path))

    # Metadata
    if not target_meta.exists():
        root_meta = BASE_DIR / f"meta_{category}.jsonl"
        if root_meta.exists():
            shutil.move(str(root_meta), str(target_meta))
        else:
            gz_path = category_dir / f"meta_{category}.jsonl.gz"
            if download_file(f"{META_BASE_URL}meta_{category}.jsonl.gz", str(gz_path)):
                decompress_gz(str(gz_path))

    return str(target_reviews), str(target_meta)

def clean_text(text: str) -> str:
    """Remove HTML tags and normalize whitespace."""
    if not isinstance(text, str):
        return ""
    if '<' in text and '>' in text:
        text = re.sub(r'<[^>]+>', '', text)
    return re.sub(r"\s+", " ", text).strip()

def prepare_review_context(reviews: List[Dict]) -> str:
    """
    Format review context for API:
    - Filter: 20-1500 chars
    - Format: 'Review N: {text}' (no title)
    - Limit: 30 reviews max
    """
    texts = []
    count = 0

    for r in reviews:
        if count >= MAX_REVIEWS_INPUT:
            break

        text = clean_text(r.get('text', ''))

        if len(text) < 20 or len(text) > 1500:
            continue

        texts.append(f'Review {count+1}: {text}')
        count += 1

    return '\n\n'.join(texts)

def validate_triplets_strict(triplets: Dict) -> bool:
    """
    Validate triplet quality:
    - Simple: no bullets
    - Complex/Hallucinated: must have (+), (-), or (~)
    - All: min 10 words, no rejection phrases
    """
    if not triplets or len(triplets) != 3:
        return False

    rejection_phrases = ["cannot", "unable to", "sorry", "language model", "ai assistant"]

    for key, text in triplets.items():
        if not text or len(text.split()) < 10:
            return False
        if any(p in text.lower() for p in rejection_phrases):
            return False

    # Simple: no bullets
    if re.search(r'\(\+\)|\(-\)', triplets['simple']):
        return False

    # Complex/Hallucinated: must have bullets
    for key in ['complex', 'hallucinated']:
        if not re.search(r'\(\+\)|\(-\)|\(~\)', triplets[key]):
            return False

    return True

def generate_triplet_data(reviews: List[Dict]) -> Optional[Dict]:
    """
    Generate SFT/DPO triplets via API:
    - Simple (A1): beginner-friendly paragraph
    - Complex (C1): professional bulleted list with controversy handling
    - Hallucinated: Complex-style with 1 subtle error
    """
    context = prepare_review_context(reviews)

    if not context.strip():
        return None

    tasks = {
        "simple": {
            "temp": 0.3,
            "max_tokens": 150,
            "prompt": f"""Summarize these reviews for a beginner (CEFR A1).

Requirements:
- Use simple present tense, basic vocabulary.
- Write 1 paragraph of 3-4 short sentences.
- NO bullet points.
- Structure: [Overall] + [Feature] + [Conclusion].
- Reflect what most people say, but mention important issues if some people have them.

Reviews:
{context}

Output ONLY the summary."""
        },

        "complex": {
            "temp": 0.3,
            "max_tokens": 300,
            "prompt": f"""Summarize these reviews in a professional, analytical style (CEFR C1).

Requirements:
1. **Style**: Use sophisticated vocabulary and phrasing, identical to a high-quality expert review.

2. **Format**: Use a bulleted list with EXACTLY 3-6 points total.
   - **CRITICAL**: EVERY point MUST start with `(+)`, `(-)`, or `(~)`.
   - Use `(+)` for consensus strengths.
   - Use `(-)` for consensus weaknesses.
   - Use `(~)` for mixed/controversial opinions (CRITICAL).
   - **Order**: List all `(+)` first, then `(-)`, then `(~)`. Do NOT mix them randomly.
   - **Compact output**: No blank lines between points. Each point on a new line immediately after the previous one.

3. **Handling Contradictions**:
   - If User A says "great battery" but User B says "battery died", you MUST report this as an inconsistency.
   - Use phrases like "Polarized feedback regarding...", "Inconsistent reports on...", or "While most praise X, some users note Y...".

4. **Length**: Total summary under 180 words. Each point 18-30 words.

Reviews:
{context}

Output ONLY the structured summary."""
        },

        "hallucinated": {
            "temp": 0.5,
            "max_tokens": 300,
            "prompt": f"""Summarize these reviews in a professional, analytical style (CEFR C1). CRITICAL: Include EXACTLY ONE subtle factual error for training purposes.

Requirements:
1. **Style**: Use sophisticated vocabulary and phrasing, identical to a high-quality expert review.

2. **Format**: Use a bulleted list with EXACTLY 3-6 points total.
   - **CRITICAL**: EVERY point MUST start with `(+)`, `(-)`, or `(~)`.
   - Use `(+)` for consensus strengths.
   - Use `(-)` for consensus weaknesses.
   - Use `(~)` for mixed/controversial opinions (CRITICAL).
   - **Order**: List all `(+)` first, then `(-)`, then `(~)`. Do NOT mix them randomly.
   - **Compact output**: No blank lines between points. Each point on a new line immediately after the previous one.

3. **Handling Contradictions**:
   - If User A says "great battery" but User B says "battery died", you MUST report this as an inconsistency.
   - Use phrases like "Polarized feedback regarding...", "Inconsistent reports on...", or "While most praise X, some users note Y...".

4. **Error Injection (CRITICAL)**:
   Inject EXACTLY ONE subtle factual error. Randomly choose ONE type:
   - **Attribute Error**: Mention a feature or accessory NOT present.
   - **Quantity Error**: Alter a specific number or measurement mentioned.
   - **Sentiment Error**: Reverse the consensus opinion on one specific aspect.
   - **Comparison Error**: Add a false competitive claim.

   *The error must be SUBTLE and realistic. It should blend in naturally with the rest of the text.*

5. **Length**: Total summary under 180 words. Each point 18-30 words.

Reviews:
{context}

Output ONLY the summary with the error. DO NOT include any notes or explanations about the error."""
        }
    }

    # Retry logic (3 attempts)
    for attempt in range(3):
        try:
            batch = {}
            for key, config in tasks.items():
                response = client.chat.completions.create(
                    model=MODEL_NAME,
                    messages=[{"role": "user", "content": config["prompt"]}],
                    temperature=config["temp"],
                    max_tokens=config["max_tokens"]
                )
                content = response.choices[0].message.content.strip()
                content = re.sub(r'^["\']|["\']$', '', content)
                content = re.sub(r'^(Summary|Output):\s*', '', content, flags=re.IGNORECASE)
                batch[key] = content

            if validate_triplets_strict(batch):
                return batch

        except Exception as e:
            if "429" in str(e):
                time.sleep(3 * (2 ** attempt))
            elif "context_length" in str(e):
                return None
            else:
                time.sleep(1)

    return None


def main():
    categories = [
        "Electronics", "Books", "Home_and_Kitchen", "Beauty_and_Personal_Care",
        "Clothing_Shoes_and_Jewelry", "Toys_and_Games", "Sports_and_Outdoors",
        "Pet_Supplies", "Automotive", "Office_Products"
    ]

    total_generated = 0
    print(f"🚀 Starting DPO Data Generation (V2.0) | Target: {len(categories)} × {SAMPLES_PER_CATEGORY}")

    for category in tqdm(categories, desc="Categories"):

        reviews_path, _ = ensure_data_files(category)
        output_dir = BASE_DIR / category
        output_file = output_dir / f"{category}_dpo_v2.jsonl"
        processed_input_path = output_dir / f"{category}_products.jsonl"

        # Load or aggregate products
        products_pool = []
        if processed_input_path.exists():
            with open(processed_input_path, 'r', encoding='utf-8') as f:
                for line in f:
                    try:
                        products_pool.append(json.loads(line))
                    except:
                        continue
        else:
            print(f"Aggregating raw reviews for {category}...")
            raw_map = defaultdict(list)
            with open(reviews_path, 'r', encoding='utf-8') as f:
                for line in f:
                    try:
                        r = json.loads(line)
                        if 'parent_asin' in r and 'text' in r:
                            raw_map[r['parent_asin']].append(r)
                    except:
                        continue

            for asin, revs in raw_map.items():
                if len(revs) >= MIN_REVIEWS_PER_PRODUCT:
                    products_pool.append({"parent_asin": asin, "reviews": revs})

        if not products_pool:
            continue
        selected_products = random.sample(products_pool, min(len(products_pool), SAMPLES_PER_CATEGORY))

        # Resume from checkpoint
        existing_asins = set()
        if output_file.exists():
            with open(output_file, 'r', encoding='utf-8') as f:
                for line in f:
                    try:
                        existing_asins.add(json.loads(line).get('parent_asin'))
                    except:
                        continue

        # Generation loop
        category_sample_printed = False

        with open(output_file, 'a', encoding='utf-8') as f_out:
            for product in tqdm(selected_products, desc=f"Gen {category}", leave=False):
                asin = product.get('parent_asin')
                if asin in existing_asins:
                    continue

                triplets = generate_triplet_data(product.get('reviews', []))

                if triplets:
                    output_data = {
                        "parent_asin": asin,
                        "category": category,
                        "product_metadata": product.get('product_metadata', {}),
                        "reviews": product.get('reviews', []),
                        "summary_simple": triplets['simple'],
                        "summary_complex": triplets['complex'],
                        "summary_hallucinated": triplets['hallucinated']
                    }

                    f_out.write(json.dumps(output_data, ensure_ascii=False) + '\n')
                    f_out.flush()
                    total_generated += 1

                    # Preview first sample per category
                    if not category_sample_printed:
                        tqdm.write(f"\n{'='*70}")
                        tqdm.write(f"📦 PREVIEW (V2.0): {category} | ASIN: {asin}")
                        tqdm.write(f"{'='*70}")
                        tqdm.write(f"\n🔷 [Simple A1] ({len(triplets['simple'].split())} words):")
                        tqdm.write(triplets['simple'])
                        tqdm.write(f"\n{'-'*70}")
                        tqdm.write(f"\n🔶 [Complex C1] ({len(triplets['complex'].split())} words):")
                        tqdm.write(triplets['complex'])
                        tqdm.write(f"\n{'-'*70}")
                        tqdm.write(f"\n⚠️  [Hallucinated] ({len(triplets['hallucinated'].split())} words):")
                        tqdm.write(triplets['hallucinated'])
                        tqdm.write(f"\n{'='*70}\n")
                        category_sample_printed = True

                time.sleep(0.5)

    print(f"\n✅ Done! Generated: {total_generated} samples in '_v2.jsonl' files.")

if __name__ == "__main__":
    main()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🚀 Starting DPO Data Generation (V2.0) | Target: 10 × 200
# Categories:   0%|          | 0/10 [00:00<?, ?it/s]
# Gen Electronics:   0%|          | 0/200 [00:00<?, ?it/s]
# ======================================================================
# 📦 PREVIEW (V2.0): Electronics | ASIN: B0047AQI4Q
# ======================================================================
#
# 🔷 [Simple A1] (71 words):
# Most people like this TV because the picture is good and it gets local channels without cable. It has a built-in DVD player and is easy to set up and use, which many find helpful. Some say the sound is weak, especially at high volume, and a few think the screen is too small or the picture not perfect. Still, it works well for small spaces like kitchens, bathrooms, or campers.
#
# ----------------------------------------------------------------------
#
# 🔶 [Complex C1] (163 words):
# (+) Consistently praised for its excellent picture quality, particularly among over-the-air users, with multiple reviewers highlighting reliable reception of local channels and seamless integration of built-in DVD functionality.
# (+) Highly valued as a compact, lightweight solution for secondary spaces—such as bathrooms, kitchens, or campers—where ease of setup, space efficiency, and integrated features outweigh the need for premium audio or screen size.
# (+) Users appreciate the intuitive interface, automatic DVD detection, and straightforward controls, which enhance usability without requiring additional equipment or complex configuration.
# (-) Audio performance is frequently cited as underwhelming; while some accept it as acceptable for the form factor, others report critically low maximum volume, limiting utility in noisy environments.
# (-) Several reviewers note the unit’s extreme lightness compromises stability, making it susceptible to displacement—even by pets—necessitating wall mounting for secure use.
# (~) While most commend the picture, a minority find it merely adequate, suggesting expectations should be tempered at this price point, especially when compared to higher-end models around $200.
#
# ----------------------------------------------------------------------
#
# ⚠️  [Hallucinated] (147 words):
# (+) Picture quality consistently receives acclaim, with multiple users highlighting sharp, vibrant visuals and reliable over-the-air reception for local channels.
# (+) The integrated DVD player is frequently praised for seamless operation, automatic input switching, and ease of use in compact spaces like campers or bathrooms.
# (+) Users appreciate the lightweight design and straightforward setup, particularly noting its suitability for wall mounting in secondary rooms or recreational vehicles.
# (-) Audio performance draws criticism across several reviews, with one user noting maximum volume barely exceeds normal levels despite expectations of strong output.
# (~) While most praise the built-in tuner for accessing networks like CBS and PBS without extra equipment, some express surprise that it lacks an HDMI port for modern streaming devices.
# (~) Polarized feedback regarding sound quality: while one reviewer expected robust audio based on testimonials, another confirmed the TV includes a surprisingly effective subwoofer for its class.
#
# ======================================================================
# Gen Books:   0%|          | 0/200 [00:00<?, ?it/s]
# ======================================================================
# 📦 PREVIEW (V2.0): Books | ASIN: 1612126642
# ======================================================================
#
# 🔷 [Simple A1] (55 words):
# Most people like this cookbook because it has tasty recipes with maple syrup. The book shows nice pictures and gives useful tips about real maple syrup. Some say a few recipes are hard or need special ingredients, but most find them easy and delicious. This is a good book for people who love maple flavor.
#
# ----------------------------------------------------------------------
#
# 🔶 [Complex C1] (127 words):
# (+) Exceptional appeal for maple syrup enthusiasts, with numerous reviewers praising the diverse, flavorful, and inventive recipes that extend beyond conventional uses.
# (+) Rich educational value highlighted, particularly regarding maple syrup production and quality, enhancing the book’s utility beyond mere recipe instruction.
# (+) Lavishly praised for its aesthetic presentation, including beautiful photography and engaging design, contributing to its perceived craftsmanship and desirability.
# (-) Some disappointment expressed over limited focus on true maple-centric recipes, with early sections perceived as underdeveloped or merely showcasing syrup pairings.
# (-) A few users noted complexity in certain recipes or uncommon ingredients, potentially limiting accessibility for casual home cooks.
# (~) While most celebrate the book's originality and execution, polarized feedback exists on whether the content consistently delivers innovative maple-based dishes versus superficial applications.
#
# ----------------------------------------------------------------------
#
# ⚠️  [Hallucinated] (123 words):
# (+) Exceptional recipe diversity and depth, particularly in maple-based desserts and breakfast items, earning consistent praise for taste and creativity.
# (+) Rich educational content on maple syrup production enhances culinary value, with users highlighting the well-researched background as a standout feature.
# (+) Lavishly photographed and clearly written, the cookbook’s aesthetic and usability are universally lauded across reviews.
# (-) Some users express disappointment that early sections focus more on using syrup as a topping rather than incorporating it into complex recipes.
# (~) While most praise the ingredient accessibility, a few note that certain recipes require rare pantry items, making execution less convenient for casual cooks.
# (~) Polarized feedback regarding included kitchen tools: while no thermometer is bundled, several reviewers mistakenly believe one was provided.
#
# ======================================================================
# Gen Home_and_Kitchen:   0%|          | 0/200 [00:00<?, ?it/s]
# ======================================================================
# 📦 PREVIEW (V2.0): Home_and_Kitchen | ASIN: B00QIQZ21M
# ======================================================================
#
# 🔷 [Simple A1] (66 words):
# Most people like these lights because they are bright and have many color options. The remote control is easy to use and the lights work well for holidays and rooms. Some say the string is shorter or thinner than expected and a few had problems after a month. Overall, it is a good buy for the price but keep the remote and check the size first.
#
# ----------------------------------------------------------------------
#
# 🔶 [Complex C1] (155 words):
# (+) AC-powered design ensures consistent operation without battery dependency, while durable rubber-jacketed construction enhances longevity and safety in both indoor and outdoor settings.
# (+) Remote functionality is widely praised for intuitive control over diverse lighting modes, color options, and brightness levels, significantly enhancing user experience and decorative versatility.
# (+) Offers exceptional value with vibrant, bright LEDs that effectively illuminate spaces ranging from bedrooms to outdoor foliage, earning strong repeat-purchase intent and broad holiday applicability.
# (-) Multiple users report significant discrepancies between advertised (33 ft) and actual illuminated length, with several noting the strand is too short or densely spaced to cover intended areas effectively.
# (-) Premature failure observed across multiple units within weeks or months of use, raising concerns about long-term reliability, particularly in outdoor or continuous-operation environments.
# (~) While most commend the uniformity and vividness of colors, inconsistent reports emerge regarding color synchronization—some strands exhibit random malfunctions where sections display incorrect or erratic behavior.
#
# ----------------------------------------------------------------------
#
# ⚠️  [Hallucinated] (124 words):
# (+) Offers an extensive array of color and lighting effects, with a user-friendly remote enhancing customization and ambiance for various occasions.
# (+) Durable construction with a protective rubberized jacket provides resilience against physical contact and outdoor elements, impressing long-term users.
# (+) AC-powered design ensures continuous operation without battery dependency, contributing to sustained performance in permanent installations.
# (-) Multiple users report significant discrepancies between advertised and actual length, with the illuminated segment falling drastically short of the claimed 33 feet.
# (-) Polarized feedback regarding longevity: while many praise durability, several confirm complete failure within weeks despite proper indoor use.
# (~) While most praise brightness and visual appeal, inconsistent color synchronization across the strand—such as mismatched hues during mode transitions—elicits mixed reactions, particularly in static displays.
#
# ======================================================================
# Gen Beauty_and_Personal_Care:   0%|          | 0/200 [00:00<?, ?it/s]
# ======================================================================
# 📦 PREVIEW (V2.0): Beauty_and_Personal_Care | ASIN: B09GF6K8B5
# ======================================================================
#
# 🔷 [Simple A1] (56 words):
# Overall, these perm rods are cheap and work well for curling hair. Some people say the rubber ends break or snap off easily, and they can hurt if they hit your skin. Many find them poorly made, with stiff plastic and weak bands. They are okay to use if needed, but not very strong or long-lasting.
#
# ----------------------------------------------------------------------
#
# 🔶 [Complex C1] (135 words):
# (+) Offer exceptional value for money, with users consistently noting the high quantity provided at a low cost compared to retail alternatives.
# (+) Effectively curl hair, with multiple reviewers confirming strong performance in achieving desired wave and curl patterns when rods remain secured.
# (-) Suffer from significant durability issues—numerous reports cite broken or poorly knotted rubber ends, with elastics snapping during application, under heat, or while rinsing.
# (-) Frequent complaints about bands detaching unexpectedly, causing discomfort (e.g., snapping on fingers) and requiring rewrapping, undermining reliability during use.
# (~) While most praise affordability and curling efficacy, some users express frustration over stiff plastic construction contributing to breakage and poor elasticity retention.
# (~) Polarized feedback regarding usability: while several deem them acceptable for emergency or temporary use, others consider them fundamentally flawed and unfit for regular styling.
#
# ----------------------------------------------------------------------
#
# ⚠️  [Hallucinated] (128 words):
# (+) Offers exceptional value for money, with users consistently praising the high quantity provided at a fraction of retail beauty supply prices.
# (+) Delivers effective curl formation on diverse hair types, with multiple reviewers confirming strong performance in achieving desired wave patterns.
# (-) Exhibits significant durability issues, as numerous users reported snapped rods, broken elastics, and poorly secured rubber ends during standard use.
# (-) Presents safety concerns due to sudden snapping under tension, with several testers noting painful recoil incidents during application or drying.
# (~) While most praise the product’s curling efficiency, some users note inconsistent quality control, with batches varying markedly in structural integrity.
# (~) Polarized feedback regarding the included metal clips—though not actually part of the set—some assume they enhance utility, while others report missing components.
#
# ======================================================================
# Gen Clothing_Shoes_and_Jewelry:   0%|          | 0/200 [00:00<?, ?it/s]
# ======================================================================
# 📦 PREVIEW (V2.0): Clothing_Shoes_and_Jewelry | ASIN: B0074GKXZK
# ======================================================================
#
# 🔷 [Simple A1] (45 words):
# The bag is cute and many people like it. It is small and only fits things like keys or chapstick, not a big phone. Some say it is smaller or lighter in color than expected. Most are happy with it but check the size first.
#
# ----------------------------------------------------------------------
#
# 🔶 [Complex C1] (117 words):
# (+) Widely praised for its charming, compact design, with multiple users highlighting its aesthetic appeal and suitability as a stylish, minimalist accessory.
# (+) Appreciated for its balanced size—neither overly bulky nor impractically tiny—making it ideal for carrying small essentials with ease and elegance.
# (-) Frequently criticized for being significantly smaller than expected, particularly in relation to the price, which some consider disproportionate given its limited capacity.
# (-) Several users reported discrepancies in color accuracy, noting that the actual product appears lighter or different from online images, leading to mild dissatisfaction.
# (~) While most find the size convenient, polarized feedback exists regarding functionality: one user notes it fits only keys and chapstick, while another deems it perfectly proportioned.
#
# ----------------------------------------------------------------------
#
# ⚠️  [Hallucinated] (117 words):
# (+) Compact and stylish design consistently praised, with users highlighting its aesthetic appeal and suitability for minimalist carry.
# (+) Lightweight construction enhances portability, making it ideal for casual outings where minimal essentials are required.
# (-) Multiple reviewers report the item is significantly smaller than anticipated, raising concerns about practicality and value for money.
# (-) Inconsistent color representation noted across reviews, with several users indicating discrepancies between online images and received product.
# (~) While most praise its charm and cuteness, polarized feedback regarding internal capacity—some find it sufficient, others note limited space for larger smartphones.
# (~) Some users appreciate the inclusion of a detachable crossbody strap for versatility, though this accessory was not actually included in the product.
#
# ======================================================================
# Gen Toys_and_Games:   0%|          | 0/200 [00:00<?, ?it/s]
# ======================================================================
# 📦 PREVIEW (V2.0): Toys_and_Games | ASIN: B07Y1JC859
# ======================================================================
#
# 🔷 [Simple A1] (44 words):
# Most people say these balloons are great for party decoration and good value. They are bright, big, and many like the Fortnite design. Some balloons had holes and lost air, so they did not last. But most are happy and would buy them again.
#
# ----------------------------------------------------------------------
#
# 🔶 [Complex C1] (122 words):
# (+) Exceptional value for money, with multiple reviewers emphasizing high quality relative to price and abundant quantity per pack.
# (+) Ideal for Fortnite-themed events, consistently praised for vibrant colors, appealing design, and effectiveness in enhancing party decor.
# (+) Praised for fast shipping and versatility—users creatively repurposed deflated balloons as makeshift volleyballs, adding unexpected entertainment value.
# (-) Significant durability issues reported: several balloons developed leaks immediately upon inflation, rendering a portion of the batch unusable despite promising initial appearance.
# (-) Inconsistent product performance: while most received fully functional balloons, one user experienced total failure across multiple units due to manufacturing defects.
# (~) While the majority highlight excellent quality, polarized feedback exists regarding structural integrity—most praise longevity, but a notable minority report rapid deflation.
#
# ----------------------------------------------------------------------
#
# ⚠️  [Hallucinated] (130 words):
# (+) Exceptional value proposition highlighted across multiple reviews, with users consistently praising the high quantity and vibrant design relative to cost.
# (+) Robust visual appeal noted for themed décor purposes, particularly in creating immersive environments for children's celebrations centered on popular culture motifs.
# (-) Significant durability concerns emerged, as one user reported all tested balloons developed leaks immediately upon inflation, suggesting potential material integrity flaws.
# (-) Inconsistent reports on functionality: while most praise longevity, one reviewer confirmed the balloons deflated within seconds due to manufacturing defects.
# (~) Polarized feedback regarding utility beyond decoration; while most treat them as disposable décor, one innovative user repurposed deflated versions as impromptu volleyballs.
# (~) While most praise the inclusion of a complimentary helium tank, shipping details indicate no gas was actually included with purchase.
#
# ======================================================================
# Gen Sports_and_Outdoors:   0%|          | 0/200 [00:00<?, ?it/s]
# ======================================================================
# 📦 PREVIEW (V2.0): Sports_and_Outdoors | ASIN: B07HCV3R3X
# ======================================================================
#
# 🔷 [Simple A1] (62 words):
# This golf mat is good for practicing at home and helps stop damage to the grass. It comes with tees and balls and works on different surfaces like grass or concrete. Some people say it moves when hit or does not last long. Overall, many are happy with it for the price, but a few find it too light or poor quality.
#
# ----------------------------------------------------------------------
#
# 🔶 [Complex C1] (143 words):
# (+) Effectively prevents turf damage and enables convenient home practice, particularly valued for backyard, garage, and indoor use with foam or practice balls.
# (+) Includes useful accessories such as tees, practice balls, and rubber inserts, enhancing versatility for chipping, driving, and swing training across varied surfaces.
# (+) Offers good initial value for the price, with many users reporting satisfaction in short-term use and ease of setup on concrete, grass, and tile.
# (-) Durability concerns are widespread, with multiple reports of severe wear, bubbling, or breakdown within weeks or after approximately 2,000 impacts.
# (-) Frequently criticized for instability—mat moves, slides, or curls during use, especially on hard surfaces, requiring anchoring or additional securing measures.
# (~) While most praise its utility for beginners and casual practice, polarized feedback exists regarding material quality, thickness, and whether it meets advertised specifications like rubber base or included tees.
#
# ----------------------------------------------------------------------
#
# ⚠️  [Hallucinated] (122 words):
# (+) Delivers effective protection against turf damage, making it ideal for backyard and indoor practice sessions without causing divots.
# (+) Includes a set of foam balls, plastic tees, and two rubber tees of varying heights, enhancing usability for different shot types.
# (+) Praised by educators and families alike for introducing young players to golf in a safe, controlled environment.
# (-) Durability concerns are widespread, with multiple users reporting significant wear, bubbling, or breakdown after minimal use.
# (-) Frequently criticized for lacking sufficient weight or anchoring, resulting in the mat shifting or flying during impact.
# (~) While most praise the included accessories, some note the absence of a heavy rubber base as advertised, though one reviewer confirmed inclusion of a removable rubber tee.
#
# ======================================================================
# Gen Pet_Supplies:   0%|          | 0/200 [00:00<?, ?it/s]
# ======================================================================
# 📦 PREVIEW (V2.0): Pet_Supplies | ASIN: B096FL718B
# ======================================================================
#
# 🔷 [Simple A1] (70 words):
# Most people like this hideout because it is strong, easy to clean, and a good size for small hamsters. It stays cool and helps pets feel safe, and many say their hamsters sleep in it. Some gerbils can get stuck if the hole faces down, and it is too small for big hamsters like Syrians. Overall, it is a nice home for dwarf or robo hamsters and chew-proof for gerbils.
#
# ----------------------------------------------------------------------
#
# 🔶 [Complex C1] (140 words):
# (+) Exceptional durability and chew resistance, particularly valued by owners of destructive rodents; ceramic construction ensures longevity and ease of cleaning.
# (+) Ideal thermal regulation and odor control, with multiple users noting its effectiveness in maintaining comfortable temperatures and hygiene for dwarf and Syrian hamsters.
# (+) Spacious interior accommodates bedding and allows natural nesting behaviors, widely praised as cozy and inviting by both hamsters and gerbils.
# (-) Significant size discrepancies reported: while suitable for dwarfs and robos, several users emphasize it is too small for Syrians, Chinese hamsters, or squirrels despite product claims.
# (-) Safety concerns with gerbils: one incident reported of entrapment when the item overturned, raising potential risks for more active or larger species.
# (~) While most praise its sturdiness, polarized feedback exists on actual dimensions—some find it bigger than expected, others deem it insufficient for larger breeds.
#
# ----------------------------------------------------------------------
#
# ⚠️  [Hallucinated] (160 words):
# (+) Exceptional durability and chew resistance noted across multiple reviews, with users emphasizing its sturdiness even when dropped or exposed to persistent gnawing from rodents.
# (+) Effortless maintenance is a consistent highlight, as the ceramic construction resists odors and simplifies cleaning, making it ideal for long-term use in small animal habitats.
# (+) Offers effective thermal regulation, with several owners observing their hamsters using it to cool down during warmer periods, indicating functional design benefits beyond mere shelter.
# (-) Safety concerns arise with gerbils, as one user reported an individual becoming trapped when the enclosure shifted, highlighting potential risks if not secured properly within the cage.
# (~) While most agree it accommodates dwarf and Syrian hamsters comfortably, polarized feedback exists regarding size suitability—some insist it's too small for Syrians or Chinese hamsters.
# (~) Inconsistent reports on included accessories: while nine users mention ease of cleaning and design, the product does not actually come with a supplementary cardboard box for additional hiding.
#
# ======================================================================
# Gen Automotive:   0%|          | 0/200 [00:00<?, ?it/s]
# ======================================================================
# 📦 PREVIEW (V2.0): Automotive | ASIN: B004QL6UOO
# ======================================================================
#
# 🔷 [Simple A1] (46 words):
# Most people like these tires. They fit well on trucks and SUVs and give a smooth, quiet ride. Some say they feel bouncy at first but get better after a few hundred miles. The tires are strong and last long, even in rough or rocky conditions.
#
# ----------------------------------------------------------------------
#
# 🔶 [Complex C1] (114 words):
# (+) Delivers a smooth, quiet ride across varied terrain, with multiple users highlighting comfort and immediate performance post-installation.
# (+) Constructed with durable, heavy-duty materials; praised for long tread life and resilience in off-road conditions, including rock-laden paths.
# (+) Offers excellent value, consistently noted for competitive pricing compared to alternatives, enhancing cost-effectiveness for bulk purchases.
# (-) Requires extended break-in period—approximately 100 miles—during which handling may be unstable, particularly on lifted trucks over rough surfaces.
# (-) Limited real-world data on extreme heat resistance despite claims; one user explicitly awaits evaluation under intense thermal conditions.
# (~) While most report current date codes and fresh manufacturing, others imply variability in batch quality, leading to inconsistent initial driving experiences.
#
# ----------------------------------------------------------------------
#
# ⚠️  [Hallucinated] (129 words):
# (+) Exceptional durability and tread longevity are consistently highlighted, with one user reporting strong performance after 15,000 miles under demanding conditions.
# (+) Users report a smooth, quiet ride post-break-in, particularly appreciating the comfort on both paved and unpaved surfaces.
# (+) Multiple reviewers confirm accurate sizing and hassle-free fitment across heavy-duty trucks and SUVs, including F250, Silverado 2500HD, and Xterra models.
# (-) Initial ride quality drew complaints due to excessive bouncing, requiring approximately 100–200 miles to stabilize, suggesting a prolonged break-in period.
# (-) While most praise long-term resilience, there are inconsistent reports on early handling stability, especially on rough terrain immediately after installation.
# (~) Polarized feedback regarding heat resistance emerges, as while most users operate in varied climates, one reviewer specifically questioned performance under INTENSE heat despite no observed degradation.
#
# ======================================================================
# Gen Office_Products:   0%|          | 0/200 [00:00<?, ?it/s]
# ======================================================================
# 📦 PREVIEW (V2.0): Office_Products | ASIN: B07WCQQMXQ
# ======================================================================
#
# 🔷 [Simple A1] (60 words):
# Most people say this sharpener works well and is easy to use. It sharpens pencils by itself and pushes them out when done, which many like. It is good for regular and colored pencils but some say it can chew them up or take too much off. A few people had problems with it not working or hurting their pencils.
#
# ----------------------------------------------------------------------
#
# 🔶 [Complex C1] (125 words):
# (+) Effortless automatic operation praised for hands-free sharpening, with smooth performance and self-ejecting mechanism ideal for classrooms and office use.
# (+) Sturdy build quality and large shaving canister noted as durable and practical for frequent use, especially with standard pencils.
# (+) Delivers precise, long-point sharpening particularly effective for colored pencils, enhancing usability for artistic and educational purposes.
# (-) Multiple users report destructive malfunctioning, including pencils being chewed, over-sharpened, or completely consumed due to failure to stop or eject properly.
# (-) Persistent reliability issues emerge over time, with devices seizing up or requiring forceful extraction of pencils after initial functional period.
# (~) While most praise its automation, inconsistent reports on pencil compatibility: some laud universal fit, others note difficulty with hexagonal or thicker pencils like Prismacolor.
#
# ----------------------------------------------------------------------
#
# ⚠️  [Hallucinated] (104 words):
# (+) Delivers consistent, hands-free sharpening with an automatic ejection mechanism praised for classroom and office efficiency.
# (+) Robust build quality and large shaving reservoir enhance usability, particularly for frequent or shared use environments.
# (-) Multiple users report severe functional defects, including failure to stop sharpening and complete destruction of pencils.
# (-) Inconsistent performance across pencil types; struggles with hexagonal and thicker art pencils despite advertised versatility.
# (~) While most praise the self-feeding mechanism, some note it aggressively shortens pencils—though claims of losing over two inches appear exaggerated.
# (~) Polarized feedback regarding durability: several highlight long-term reliability, whereas others describe rapid deterioration after minimal use.
#
# ======================================================================
#
#
# ✅ Done! Generated: 1964 samples in '_v2.jsonl' files.
