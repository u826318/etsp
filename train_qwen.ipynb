# %%
# %%capture
# Installs Unsloth, Xformers, and TRL
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps xformers trl peft accelerate bitsandbytes datasets

# %%
# ==========================================
# 0. Environment Setup
# ==========================================
import os
try:
    import unsloth
except ImportError:
    print("Installing Unsloth...")
    os.system("pip install -q 'unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git'")
    os.system("pip install -q --no-deps xformers trl peft accelerate bitsandbytes datasets")

# ==========================================
# 1. Configuration
# ==========================================
import torch
import json
import glob
import gc
import re
from unsloth import FastLanguageModel, PatchDPOTrainer
from trl import SFTTrainer, DPOTrainer, DPOConfig
from transformers import TrainingArguments
from datasets import Dataset
from unsloth.chat_templates import get_chat_template

# Paths
DATA_DIR = "/content/drive/MyDrive/ETSP"
OUTPUT_DIR_SFT = "/content/drive/MyDrive/ETSP/qwen_sft_v2"
OUTPUT_DIR_DPO = "/content/drive/MyDrive/ETSP/qwen_dpo_v2"

# Model Configuration
MODEL_NAME = "unsloth/Qwen2.5-3B-Instruct-bnb-4bit"
MAX_SEQ_LENGTH = 8192  # Extended context for 30 reviews + prompt
DTYPE = None
LOAD_IN_4BIT = True

# Mount Google Drive
from google.colab import drive
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

# ==========================================
# 2. Data Processing
# ==========================================
def clean_text(text: str) -> str:
    """Remove HTML tags and normalize whitespace."""
    if not isinstance(text, str):
        return ""
    if '<' in text and '>' in text:
        text = re.sub(r'<[^>]+>', '', text)
    return re.sub(r"\s+", " ", text).strip()

def format_review_context(reviews_list):
    """
    Reconstruct review context matching generation pipeline:
    - Clean text with clean_text()
    - Filter by length: 20-1500 chars
    - Format: 'Review N: {text}' (no title)
    - Max 30 reviews per product
    """
    texts = []
    count = 0

    for r in reviews_list:
        if count >= 30:
            break

        text = clean_text(r.get('text', ''))

        if len(text) < 20 or len(text) > 1500:
            continue

        texts.append(f'Review {count+1}: {text}')
        count += 1

    return '\n\n'.join(texts)

def load_datasets(data_dir):
    """
    Load *_dpo_v2.jsonl files and construct SFT/DPO datasets.

    SFT: Learns readability control (A1/C1) and format adherence
    DPO: Learns hallucination rejection via preference optimization
    """
    files = glob.glob(os.path.join(data_dir, "**/*_dpo_v2.jsonl"), recursive=True)
    print(f"Found {len(files)} data files.")

    sft_data = []
    dpo_data = []

    for file_path in files:
        with open(file_path, 'r', encoding='utf-8') as f:
            for line in f:
                try:
                    item = json.loads(line)
                    reviews = item.get('reviews', [])
                    if not reviews: continue

                    context = format_review_context(reviews)
                    if not context.strip(): continue

                    simple = item.get('summary_simple')
                    complex_ = item.get('summary_complex')
                    hallucinated = item.get('summary_hallucinated')

                    if not (simple and complex_ and hallucinated): continue

                    # A1 (Simple) Prompt - matches generation exactly
                    a1_instruction = """Summarize these reviews for a beginner (CEFR A1).

Requirements:
- Use simple present tense, basic vocabulary.
- Write 1 paragraph of 3-4 short sentences.
- NO bullet points.
- Structure: [Overall] + [Feature] + [Conclusion].
- Reflect what most people say, but mention important issues if some people have them.

Reviews:
{context}

Output ONLY the summary.""".format(context=context)

                    # C1 (Complex) Prompt - matches generation exactly
                    c1_instruction = """Summarize these reviews in a professional, analytical style (CEFR C1).

Requirements:
1. **Style**: Use sophisticated vocabulary and phrasing, identical to a high-quality expert review.

2. **Format**: Use a bulleted list with EXACTLY 3-6 points total.
   - **CRITICAL**: EVERY point MUST start with `(+)`, `(-)`, or `(~)`.
   - Use `(+)` for consensus strengths.
   - Use `(-)` for consensus weaknesses.
   - Use `(~)` for mixed/controversial opinions (CRITICAL).
   - **Order**: List all `(+)` first, then `(-)`, then `(~)`. Do NOT mix them randomly.
   - **Compact output**: No blank lines between points. Each point on a new line immediately after the previous one.

3. **Handling Contradictions**:
   - If User A says "great battery" but User B says "battery died", you MUST report this as an inconsistency.
   - Use phrases like "Polarized feedback regarding...", "Inconsistent reports on...", or "While most praise X, some users note Y...".

4. **Length**: Total summary under 180 words. Each point 18-30 words.

Reviews:
{context}

Output ONLY the structured summary.""".format(context=context)

                    # SFT samples (both readability levels)
                    sft_data.append({
                        "instruction": a1_instruction,
                        "output": simple
                    })
                    sft_data.append({
                        "instruction": c1_instruction,
                        "output": complex_
                    })

                    # DPO samples (C1 only - hallucination detection)
                    dpo_data.append({
                        "question": c1_instruction,
                        "chosen": complex_,
                        "rejected": hallucinated
                    })

                except Exception:
                    continue

    print(f"Loaded: {len(sft_data)} SFT samples | {len(dpo_data)} DPO pairs")

    # 90/10 train/val split
    ds_sft = Dataset.from_list(sft_data).train_test_split(test_size=0.1, seed=42)
    ds_dpo = Dataset.from_list(dpo_data).train_test_split(test_size=0.1, seed=42)

    return ds_sft, ds_dpo

# Load datasets
dataset_sft, dataset_dpo = load_datasets(DATA_DIR)
print(f"SFT Train: {len(dataset_sft['train'])}, Val: {len(dataset_sft['test'])}")
print(f"DPO Train: {len(dataset_dpo['train'])}, Val: {len(dataset_dpo['test'])}")

# ==========================================
# 3. Stage 1: Supervised Fine-Tuning (SFT)
# ==========================================
print("\n🚀 [Stage 1] SFT Training")

# Load base model
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = MODEL_NAME,
    max_seq_length = MAX_SEQ_LENGTH,
    dtype = DTYPE,
    load_in_4bit = LOAD_IN_4BIT,
)

# Add LoRA adapters
model = FastLanguageModel.get_peft_model(
    model,
    r = 16,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
    lora_alpha = 16,
    lora_dropout = 0,
    bias = "none",
    use_gradient_checkpointing = "unsloth",
    random_state = 3407,
)

# Apply Qwen 2.5 chat template
tokenizer = get_chat_template(
    tokenizer,
    chat_template = "qwen-2.5",
    mapping = {"role": "role", "content": "content", "user": "user", "assistant": "assistant"}
)

def format_sft_func(examples):
    """Apply chat template to SFT samples."""
    texts = []
    for inst, out in zip(examples["instruction"], examples["output"]):
        conv = [
            {"role": "user", "content": inst},
            {"role": "assistant", "content": out}
        ]
        texts.append(tokenizer.apply_chat_template(conv, tokenize=False, add_generation_prompt=False))
    return {"text": texts}

dataset_sft_fmt = dataset_sft.map(format_sft_func, batched=True)

# SFT Trainer
trainer_sft = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset_sft_fmt['train'],
    eval_dataset = dataset_sft_fmt['test'],
    dataset_text_field = "text",
    max_seq_length = MAX_SEQ_LENGTH,
    dataset_num_proc = 2,
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_ratio = 0.1,
        num_train_epochs = 2,
        learning_rate = 5e-5,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        logging_steps = 10,
        eval_strategy = "steps",
        eval_steps = 50,
        save_strategy = "steps",
        save_steps = 100,
        save_total_limit = 3,
        load_best_model_at_end = True,
        metric_for_best_model = "eval_loss",
        optim = "adamw_8bit",
        output_dir = OUTPUT_DIR_SFT,
        seed = 3407,
    ),
)

trainer_sft.train()
print("✅ SFT complete")

model.save_pretrained(OUTPUT_DIR_SFT)
tokenizer.save_pretrained(OUTPUT_DIR_SFT)

# ==========================================
# 4. Memory Cleanup
# ==========================================
del model, tokenizer, trainer_sft
gc.collect()
torch.cuda.empty_cache()
print("🧹 Memory cleared")

# ==========================================
# 5. Stage 2: Direct Preference Optimization (DPO)
# ==========================================
print("\n🚀 [Stage 2] DPO Training")

# Reload model with SFT weights
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = OUTPUT_DIR_SFT,
    max_seq_length = MAX_SEQ_LENGTH,
    dtype = DTYPE,
    load_in_4bit = LOAD_IN_4BIT,
)

# Enable DPO training
PatchDPOTrainer()

def format_dpo_func(example):
    """Format DPO data for preference learning."""
    return {
        "prompt": tokenizer.apply_chat_template([{"role": "user", "content": example["question"]}], tokenize=False, add_generation_prompt=True),
        "chosen": example["chosen"],
        "rejected": example["rejected"],
    }

dataset_dpo_fmt = dataset_dpo.map(format_dpo_func)

# DPO Trainer
dpo_trainer = DPOTrainer(
    model = model,
    ref_model = None,  # Unsloth handles reference model internally
    tokenizer = tokenizer,
    train_dataset = dataset_dpo_fmt['train'],
    eval_dataset = dataset_dpo_fmt['test'],
    max_length = MAX_SEQ_LENGTH,
    max_prompt_length = MAX_SEQ_LENGTH - 512,  # Reserve 512 tokens for output
    beta = 0.1,  # Strong preference signal for hallucination rejection
    args = DPOConfig(
        per_device_train_batch_size = 1,
        gradient_accumulation_steps = 8,
        warmup_ratio = 0.1,
        num_train_epochs = 1,
        learning_rate = 5e-6,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        logging_steps = 10,
        eval_strategy = "steps",
        eval_steps = 20,
        save_strategy = "no",
        optim = "adamw_8bit",
        output_dir = OUTPUT_DIR_DPO,
        seed = 3407,
    ),
)

dpo_trainer.train()
print("✅ DPO complete")

# ==========================================
# 6. Final Export
# ==========================================
print(f"💾 Saving to {OUTPUT_DIR_DPO}")
model.save_pretrained(OUTPUT_DIR_DPO)
tokenizer.save_pretrained(OUTPUT_DIR_DPO)
print("🎉 Training complete!")
# Out:
# Installing Unsloth...
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Found 9 data files.
# Loaded: 3554 SFT samples | 1777 DPO pairs
# SFT Train: 3198, Val: 356
# DPO Train: 1599, Val: 178
#
# 🚀 [Stage 1] SFT Training
# ==((====))==  Unsloth 2025.12.5: Fast Qwen2 patching. Transformers: 4.57.3.
#    \\   /|    NVIDIA L4. Num GPUs = 1. Max memory: 22.161 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.0+cu126. CUDA: 8.9. CUDA Toolkit: 12.6. Triton: 3.5.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.33.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.05G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/271 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# Unsloth 2025.12.5 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.
# Map:   0%|          | 0/3198 [00:00<?, ? examples/s]
# Map:   0%|          | 0/356 [00:00<?, ? examples/s]
# Unsloth: Tokenizing ["text"] (num_proc=16):   0%|          | 0/3198 [00:00<?, ? examples/s]
# Unsloth: Tokenizing ["text"] (num_proc=16):   0%|          | 0/356 [00:00<?, ? examples/s]
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 3,198 | Num Epochs = 2 | Total steps = 800
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 29,933,568 of 3,115,872,256 (0.96% trained)
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  3
# wandb: You chose "Don't visualize my results"
# Tracking run with wandb version 0.23.1
# W&B syncing is set to <code>`offline`<code> in this directory. Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.<br>Run data is saved locally in <code>/content/wandb/offline-run-20251214_005011-ajt5uv3l</code>
# wandb: Detected [huggingface_hub.inference, openai] in use.
# wandb: Use W&B Weave for improved LLM call tracing. Install Weave with `pip install weave` then add `import weave` to the top of your script.
# wandb: For more information, check out the docs at: https://weave-docs.wandb.ai/
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='800' max='800' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [800/800 1:10:03, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>2.575400</td>
#       <td>2.519796</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.026000</td>
#       <td>1.907364</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.800800</td>
#       <td>1.881023</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.881600</td>
#       <td>1.867517</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.911900</td>
#       <td>1.858518</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.832400</td>
#       <td>1.851551</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.827800</td>
#       <td>1.846871</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.805100</td>
#       <td>1.841844</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.917800</td>
#       <td>1.837860</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.824100</td>
#       <td>1.835466</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>1.803800</td>
#       <td>1.832373</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.891500</td>
#       <td>1.829918</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>1.883200</td>
#       <td>1.827950</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.822000</td>
#       <td>1.826901</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>1.834300</td>
#       <td>1.825738</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.844500</td>
#       <td>1.825496</td>
#     </tr>
#   </tbody>
# </table><p>
# Unsloth: Not an error, but Qwen2ForCausalLM does not accept `num_items_in_batch`.
# Using gradient accumulation will be very slightly less accurate.
# Read more on gradient accumulation issues here: https://unsloth.ai/blog/gradient
# wandb: WARNING URL not available in offline run
# wandb: WARNING URL not available in offline run
# wandb: WARNING URL not available in offline run
# wandb: WARNING URL not available in offline run
# wandb: WARNING URL not available in offline run
# wandb: WARNING URL not available in offline run
# wandb: WARNING URL not available in offline run
# wandb: WARNING URL not available in offline run
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/runtime</td><td>█▂▂▂▂▂▁▂▂▂▁▂▂▂▂▂</td></tr><tr><td>eval/samples_per_second</td><td>▁▇▇▇▇▇█▇▇▇█▇▇▇▇▇</td></tr><tr><td>eval/steps_per_second</td><td>▁▇▇▇▇▇█▇▇▇█▇▇▆▇▇</td></tr><tr><td>train/epoch</td><td>▁▂▂▂▂▃▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇█████</td></tr><tr><td>train/global_step</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇████</td></tr><tr><td>train/grad_norm</td><td>█▆▅▄▂▁▂▂▁▂▁▂▂▂▂▃▂▃▂▂▂▂▃▃▄▃▃▃▃▄▃▃▃▃▃▃▃▃▃▃</td></tr><tr><td>train/learning_rate</td><td>▄▄▅█████▇▇▇▇▇▇▆▆▆▆▅▅▅▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▁▁▁</td></tr><tr><td>train/loss</td><td>█▇▇▆▅▃▂▂▂▂▂▂▂▁▂▁▁▁▁▁▂▂▂▂▁▁▁▁▂▁▁▁▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>1.8255</td></tr><tr><td>eval/runtime</td><td>58.7558</td></tr><tr><td>eval/samples_per_second</td><td>6.059</td></tr><tr><td>eval/steps_per_second</td><td>3.029</td></tr><tr><td>total_flos</td><td>9.902415246178714e+16</td></tr><tr><td>train/epoch</td><td>2</td></tr><tr><td>train/global_step</td><td>800</td></tr><tr><td>train/grad_norm</td><td>0.28802</td></tr><tr><td>train/learning_rate</td><td>0.0</td></tr><tr><td>train/loss</td><td>1.8445</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br><code>wandb sync /content/wandb/offline-run-20251214_005011-ajt5uv3l<code>
# Find logs at: <code>./wandb/offline-run-20251214_005011-ajt5uv3l/logs</code>
# ✅ SFT complete
# 🧹 Memory cleared
#
# 🚀 [Stage 2] DPO Training
# ==((====))==  Unsloth 2025.12.5: Fast Qwen2 patching. Transformers: 4.57.3.
#    \\   /|    NVIDIA L4. Num GPUs = 1. Max memory: 22.161 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.0+cu126. CUDA: 8.9. CUDA Toolkit: 12.6. Triton: 3.5.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.33.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Map:   0%|          | 0/1599 [00:00<?, ? examples/s]
# Map:   0%|          | 0/178 [00:00<?, ? examples/s]
# Extracting prompt in train dataset (num_proc=16):   0%|          | 0/1599 [00:00<?, ? examples/s]
# Applying chat template to train dataset (num_proc=16):   0%|          | 0/1599 [00:00<?, ? examples/s]
# Tokenizing train dataset (num_proc=16):   0%|          | 0/1599 [00:00<?, ? examples/s]
# Extracting prompt in eval dataset (num_proc=16):   0%|          | 0/178 [00:00<?, ? examples/s]
# Applying chat template to eval dataset (num_proc=16):   0%|          | 0/178 [00:00<?, ? examples/s]
# Tokenizing eval dataset (num_proc=16):   0%|          | 0/178 [00:00<?, ? examples/s]
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,599 | Num Epochs = 1 | Total steps = 200
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 8
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 8 x 1) = 8
#  "-____-"     Trainable parameters = 29,933,568 of 3,115,872,256 (0.96% trained)
# Tracking run with wandb version 0.23.1
# W&B syncing is set to <code>`offline`<code> in this directory. Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.<br>Run data is saved locally in <code>/content/wandb/offline-run-20251214_020119-29er2xsw</code>
#     <div>
#
#       <progress value='200' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [200/200 45:10, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>rewards / chosen</th>
#       <th>rewards / rejected</th>
#       <th>rewards / accuracies</th>
#       <th>rewards / margins</th>
#       <th>logps / chosen</th>
#       <th>logps / rejected</th>
#       <th>logits / chosen</th>
#       <th>logits / rejected</th>
#       <th>eval_logits / chosen</th>
#       <th>eval_logits / rejected</th>
#       <th>nll_loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>20</td>
#       <td>0.852200</td>
#       <td>0.592342</td>
#       <td>13.255346</td>
#       <td>11.899546</td>
#       <td>0.711111</td>
#       <td>1.355799</td>
#       <td>-379.436462</td>
#       <td>-404.503113</td>
#       <td>-0.622687</td>
#       <td>-0.590356</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.530400</td>
#       <td>0.323342</td>
#       <td>12.162534</td>
#       <td>9.678000</td>
#       <td>0.844444</td>
#       <td>2.484532</td>
#       <td>-390.364594</td>
#       <td>-426.718628</td>
#       <td>-0.771685</td>
#       <td>-0.724624</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.279700</td>
#       <td>0.203208</td>
#       <td>10.942546</td>
#       <td>7.571390</td>
#       <td>0.922222</td>
#       <td>3.371155</td>
#       <td>-402.564484</td>
#       <td>-447.784668</td>
#       <td>-0.927748</td>
#       <td>-0.868945</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.155000</td>
#       <td>0.137324</td>
#       <td>9.493854</td>
#       <td>5.340331</td>
#       <td>0.938889</td>
#       <td>4.153523</td>
#       <td>-417.051392</td>
#       <td>-470.095276</td>
#       <td>-1.059625</td>
#       <td>-0.990322</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.215100</td>
#       <td>0.106404</td>
#       <td>8.069264</td>
#       <td>3.231753</td>
#       <td>0.955556</td>
#       <td>4.837512</td>
#       <td>-431.297302</td>
#       <td>-491.181122</td>
#       <td>-1.188316</td>
#       <td>-1.110057</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.175700</td>
#       <td>0.089143</td>
#       <td>6.999538</td>
#       <td>1.613979</td>
#       <td>0.961111</td>
#       <td>5.385560</td>
#       <td>-441.994537</td>
#       <td>-507.358826</td>
#       <td>-1.277033</td>
#       <td>-1.191818</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.129700</td>
#       <td>0.078113</td>
#       <td>6.081824</td>
#       <td>0.248831</td>
#       <td>0.966667</td>
#       <td>5.832993</td>
#       <td>-451.171661</td>
#       <td>-521.010254</td>
#       <td>-1.358885</td>
#       <td>-1.266958</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.037800</td>
#       <td>0.072495</td>
#       <td>5.693827</td>
#       <td>-0.391511</td>
#       <td>0.966667</td>
#       <td>6.085338</td>
#       <td>-455.051697</td>
#       <td>-527.413696</td>
#       <td>-1.390653</td>
#       <td>-1.296496</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.068900</td>
#       <td>0.070677</td>
#       <td>5.400839</td>
#       <td>-0.835406</td>
#       <td>0.966667</td>
#       <td>6.236245</td>
#       <td>-457.981567</td>
#       <td>-531.852661</td>
#       <td>-1.414287</td>
#       <td>-1.317963</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.120300</td>
#       <td>0.069946</td>
#       <td>5.352250</td>
#       <td>-0.913489</td>
#       <td>0.966667</td>
#       <td>6.265739</td>
#       <td>-458.467438</td>
#       <td>-532.633484</td>
#       <td>-1.418352</td>
#       <td>-1.321566</td>
#       <td>No Log</td>
#       <td>No Log</td>
#       <td>No Log</td>
#     </tr>
#   </tbody>
# </table><p>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/logits/chosen</td><td>█▇▅▄▃▂▂▁▁▁</td></tr><tr><td>eval/logits/rejected</td><td>█▇▅▄▃▂▂▁▁▁</td></tr><tr><td>eval/logps/chosen</td><td>█▇▆▅▃▂▂▁▁▁</td></tr><tr><td>eval/logps/rejected</td><td>█▇▆▄▃▂▂▁▁▁</td></tr><tr><td>eval/loss</td><td>█▄▃▂▁▁▁▁▁▁</td></tr><tr><td>eval/rewards/accuracies</td><td>▁▅▇▇██████</td></tr><tr><td>eval/rewards/chosen</td><td>█▇▆▅▃▂▂▁▁▁</td></tr><tr><td>eval/rewards/margins</td><td>▁▃▄▅▆▇▇███</td></tr><tr><td>eval/rewards/rejected</td><td>█▇▆▄▃▂▂▁▁▁</td></tr><tr><td>eval/runtime</td><td>▆▁▃▃▂▂▂▃█▅</td></tr><tr><td>+15</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/logits/chosen</td><td>-1.41835</td></tr><tr><td>eval/logits/rejected</td><td>-1.32157</td></tr><tr><td>eval/logps/chosen</td><td>-458.46744</td></tr><tr><td>eval/logps/rejected</td><td>-532.63348</td></tr><tr><td>eval/loss</td><td>0.06995</td></tr><tr><td>eval/rewards/accuracies</td><td>0.96667</td></tr><tr><td>eval/rewards/chosen</td><td>5.35225</td></tr><tr><td>eval/rewards/margins</td><td>6.26574</td></tr><tr><td>eval/rewards/rejected</td><td>-0.91349</td></tr><tr><td>eval/runtime</td><td>93.6106</td></tr><tr><td>+20</td><td>...</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br><code>wandb sync /content/wandb/offline-run-20251214_020119-29er2xsw<code>
# Find logs at: <code>./wandb/offline-run-20251214_020119-29er2xsw/logs</code>
# ✅ DPO complete
# 💾 Saving to /content/drive/MyDrive/ETSP/qwen_dpo_v2
# 🎉 Training complete!

# %%
import torch
from unsloth import FastLanguageModel
from transformers import TextStreamer
import json
import re
import random
import os
import glob

class Colors:
    GREEN = '\033[92m'
    RED = '\033[91m'
    YELLOW = '\033[93m'
    CYAN = '\033[96m'
    BOLD = '\033[1m'
    RESET = '\033[0m'
    GRAY = '\033[90m'

MODEL_PATH = "/content/drive/MyDrive/ETSP/qwen_dpo_v2"
DATA_DIR = "/content/drive/MyDrive/ETSP"

print(f"{Colors.CYAN}正在加载训练好的 DPO 模型: {MODEL_PATH}...{Colors.RESET}")
try:
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = MODEL_PATH,
        max_seq_length = 6144,
        dtype = None,
        load_in_4bit = True,
    )
    FastLanguageModel.for_inference(model)
    print(f"{Colors.GREEN}模型加载成功!{Colors.RESET}\n")
except Exception as e:
    print(f"{Colors.RED}模型加载失败: {e}{Colors.RESET}")
    exit()

def clean_text(text: str) -> str:
    if not isinstance(text, str): return ""
    if '<' in text and '>' in text:
        text = re.sub(r'<[^>]+>', '', text)
    return re.sub(r"\s+", " ", text).strip()

def format_review_context(reviews_list):
    texts = []
    count = 0
    for r in reviews_list:
        if count >= 30: break
        text = clean_text(r.get('text', ''))
        if len(text) < 20 or len(text) > 1500: continue
        texts.append(f'Review {count+1}: {text}')
        count += 1
    return '\n\n'.join(texts)

def load_random_sample():
    files = glob.glob(os.path.join(DATA_DIR, "**/*_dpo_v2.jsonl"), recursive=True)
    if not files:
        print(f"{Colors.RED}找不到测试数据文件 (*_dpo_v2.jsonl){Colors.RESET}")
        return None, None

    target_file = random.choice(files)
    print(f"使用数据文件: {target_file}")

    samples = []
    with open(target_file, 'r', encoding='utf-8') as f:
        for _ in range(500):
            line = f.readline()
            if not line: break
            samples.append(json.loads(line))

    return random.choice(samples), target_file

sample_data, filename = load_random_sample()
if not sample_data: exit()

context_input = format_review_context(sample_data['reviews'])
asin = sample_data.get('parent_asin', 'Unknown')
category = sample_data.get('category', 'Unknown')

print(f"{'='*60}")
print(f"产品: {category} | ASIN: {asin}")
print(f"原始评论输入 (共 {len(sample_data['reviews'])} 条, 截取前30条)")
print(f"{'='*60}")
print(f"{Colors.GRAY}{context_input[:1000]}... [由于太长只显示前1000字符]{Colors.RESET}")
print(f"{'='*60}\n")

def get_prompt(style, context):
    if style == "A1":
        return """Summarize these reviews for a beginner (CEFR A1).

Requirements:
- Use simple present tense, basic vocabulary.
- Write 1 paragraph of 3-4 short sentences.
- NO bullet points.
- Structure: [Overall] + [Feature] + [Conclusion].
- Reflect what most people say, but mention important issues if some people have them.

Reviews:
{context}

Output ONLY the summary.""".format(context=context)

    elif style == "C1":
        return """Summarize these reviews in a professional, analytical style (CEFR C1).

Requirements:
1. **Style**: Use sophisticated vocabulary and phrasing, identical to a high-quality expert review.

2. **Format**: Use a bulleted list with EXACTLY 3-6 points total.
   - **CRITICAL**: EVERY point MUST start with `(+)`, `(-)`, or `(~)`.
   - Use `(+)` for consensus strengths.
   - Use `(-)` for consensus weaknesses.
   - Use `(~)` for mixed/controversial opinions (CRITICAL).
   - **Order**: List all `(+)` first, then `(-)`, then `(~)`. Do NOT mix them randomly.
   - **Compact output**: No blank lines between points. Each point on a new line immediately after the previous one.

3. **Handling Contradictions**:
   - If User A says "great battery" but User B says "battery died", you MUST report this as an inconsistency.
   - Use phrases like "Polarized feedback regarding...", "Inconsistent reports on...", or "While most praise X, some users note Y...".

4. **Length**: Total summary under 180 words. Each point 18-30 words.

Reviews:
{context}

Output ONLY the structured summary.""".format(context=context)

def run_test(style):
    print(f"\n>>> 测试模式: {Colors.BOLD}{style} (SFT+DPO 效果验证){Colors.RESET}")

    user_prompt = get_prompt(style, context_input)

    messages = [{"role": "user", "content": user_prompt}]
    inputs = tokenizer.apply_chat_template(messages, tokenize=True, add_generation_prompt=True, return_tensors="pt").to("cuda")

    streamer = TextStreamer(tokenizer, skip_prompt=True)

    print(f"{Colors.CYAN}模型生成中...{Colors.RESET}")
    print(f"{Colors.YELLOW}{'-'*40}{Colors.RESET}")

    _ = model.generate(
        inputs,
        streamer=streamer,
        max_new_tokens=512,
        temperature=0.1,
        use_cache=True
    )
    print(f"{Colors.YELLOW}{'-'*40}{Colors.RESET}")

run_test("A1")
run_test("C1")
print(f"\n{Colors.GREEN}测试完成{Colors.RESET}")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# 正在加载训练好的 DPO 模型: /content/drive/MyDrive/ETSP/qwen_dpo_v2...
# ==((====))==  Unsloth 2025.12.7: Fast Qwen2 patching. Transformers: 4.57.3.
#    \\   /|    NVIDIA L4. Num GPUs = 1. Max memory: 22.161 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.0+cu126. CUDA: 8.9. CUDA Toolkit: 12.6. Triton: 3.5.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.33.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.05G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/271 [00:00<?, ?B/s]
# Unsloth 2025.12.7 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.
# 模型加载成功!
#
# 使用数据文件: /content/drive/MyDrive/ETSP/Pet_Supplies/Pet_Supplies_dpo_v2.jsonl
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ============================================================
# 产品: Pet_Supplies | ASIN: B01MD0MV9M
# 原始评论输入 (共 5 条, 截取前30条)
# ============================================================
# Review 1: We have been a fan of this carrier for years. It is comfortable to carry, the cats love them. They are sturdy and a bonus is that they look great.Only down side is that they are not the easiest to clean. We have put them through the washer a couple of times (the big one at the laundry mat) when a cat had an accident, even though you are not supposed to and they survived just fine but I would not do so regularly.They work great on planes (used on the flight back from Germany with our 15# cat) and for trips to the vet. It is actually possible AND comfortable to carry and stack multiple carriers!!They are expensive so we have slowly relpaced our cheaper ones and now everyone has a sleepy pod so they can stop fighting over them. Heavier cats will fit in this carrier since they can turn around, but I would not make them travel for long in it (just to the vet in our case, the 19# cat gets a BIG hard sided carrier if he flys).
#
# Review 2: Great attractive roomy feels sturdy for air t... [由于太长只显示前1000字符]
# ============================================================
#
#
# >>> 测试模式: A1 (SFT+DPO 效果验证)
# 模型生成中...
# ----------------------------------------
# Most people like this carrier because it is comfy, looks nice, and works well for trips to the vet or plane. It is strong and good for pets, but some say it is hard to clean and may not last long if used too much. Overall, many are happy with it but some think it costs too much.<|im_end|>
# ----------------------------------------
#
# >>> 测试模式: C1 (SFT+DPO 效果验证)
# 模型生成中...
# ----------------------------------------
# (+) Exceptional durability, comfort, and reliability for air travel, veterinary visits, and frequent use, with strong customer satisfaction and frequent repurchase due to safety, sturdiness, and design appeal.
# (+) Praised for aesthetic quality, ease of stacking, suitability for heavy pets, and suitability for extended travel, particularly valued for security and practicality compared to alternatives.
# (-) Cleaning challenges noted, including difficulty in washing and potential damage risk, suggesting limited washability despite occasional necessity; may compromise hygiene and longevity.
# (~) Inconsistent reports on value: while many consider it worth the cost, others view it as overpriced or unnecessary, indicating divergent perceptions of price-to-quality ratio.<|im_end|>
# ----------------------------------------
#
# 测试完成

# %%
import os
import json
import random
import re
from tqdm.auto import tqdm
from unsloth import FastLanguageModel
from datasets import Dataset
from openai import OpenAI

MODEL_PATH = "/content/drive/MyDrive/ETSP/qwen_dpo_v2"
DATA_ROOT = "/content/drive/MyDrive/ETSP"

CATEGORIES = [
    "Electronics", "Books", "Home_and_Kitchen", "Beauty_and_Personal_Care",
    "Clothing_Shoes_and_Jewelry", "Toys_and_Games", "Sports_and_Outdoors",
    "Pet_Supplies", "Automotive", "Office_Products"
]

SAMPLES_PER_CATEGORY = 5

API_KEY = "sk-996821dc137f4a0885d3bee6eca2127a"
BASE_URL = "https://dashscope.aliyuncs.com/compatible-mode/v1"
JUDGE_MODEL = "qwen-plus"

print(f"正在加载微调模型: {MODEL_PATH}...")
try:
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = MODEL_PATH,
        max_seq_length = 6144,
        dtype = None,
        load_in_4bit = True,
    )
    FastLanguageModel.for_inference(model)
    print("Student 模型加载成功")
except Exception as e:
    print(f"模型加载失败: {e}")
    exit()

def clean_text(text: str) -> str:
    if not isinstance(text, str): return ""
    if '<' in text and '>' in text: text = re.sub(r'<[^>]+>', '', text)
    return re.sub(r"\s+", " ", text).strip()

def format_context(reviews):
    texts = []
    count = 0
    for r in reviews:
        if count >= 30: break
        text = clean_text(r.get('text', ''))
        if len(text) < 20 or len(text) > 1500: continue
        texts.append(f'Review {count+1}: {text}')
        count += 1
    return '\n\n'.join(texts)

def get_unseen_samples(category, count=2):
    file_path = os.path.join(DATA_ROOT, category, f"{category}_dpo_v2.jsonl")
    if not os.path.exists(file_path):
        file_path = os.path.join(DATA_ROOT, category, f"{category}_dpo.jsonl")
        if not os.path.exists(file_path):
            print(f"跳过 {category}: 文件不存在")
            return []

    clean_data = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            try:
                item = json.loads(line)
                safe_item = {
                    "parent_asin": item.get("parent_asin", "unknown"),
                    "reviews": item.get("reviews", []),
                }
                clean_data.append(safe_item)
            except:
                continue

    if len(clean_data) < 10: return []

    try:
        ds = Dataset.from_list(clean_data)
        ds_split = ds.train_test_split(test_size=0.1, seed=42)
        test_set = ds_split['test']

        if len(test_set) > count:
            indices = random.sample(range(len(test_set)), count)
            samples = [test_set[i] for i in indices]
        else:
            samples = [item for item in test_set]

        results = []
        for item in samples:
            context = format_context(item.get('reviews', []))
            if len(context) > 200:
                item['formatted_context'] = context
                item['category'] = category
                results.append(item)

        return results

    except Exception as e:
        print(f"{category} 处理出错: {e}")
        return []

client = OpenAI(api_key=API_KEY, base_url=BASE_URL)

def evaluate_factuality(original_reviews, generated_summary, style):
    if style == "A1":
        style_requirements = """
[A1 格式要求]
- 应该是 1 段话，3-4 个简单短句
- 使用简单现在时和基础词汇
- 不应该有 bullet points
- 结构：[总体评价] + [特点] + [结论]
"""
    else:  # C1
        style_requirements = """
[C1 格式要求]
- 应该是 3-6 个 bullet points
- 每个 point 必须以 (+) / (-) / (~) 开头
- 顺序：所有 (+) 在前，然后 (-)，最后 (~)
- 使用复杂词汇和专业表达
"""

    judge_prompt = f"""
你是一位公平、客观的事实核查员。请基于下方的评论原文，检查 AI 生成的摘要内容是否属实。

[输入数据]
评论原文 (Source):
{original_reviews}

AI 生成摘要 (Summary):
{generated_summary}

{style_requirements}

[判罚标准]

PASS (合格):
1. **有据可依**: 摘要中提到的观点（无论是优点还是缺点），只要在评论原文中真实出现过（哪怕只有少数人提到），就算正确。
2. **合理归纳**: 允许模型对相似的观点进行总结概括。
3. **格式正确**: 符合 {style} 的格式要求。

FAIL (不合格):
1. **无中生有 (Fabrication)**: 提到了评论中根本不存在的参数、功能、配件或具体场景。
2. **情感反转 (Sentiment Error)**: 评论明明说是"缺点"，摘要却写成了"优点"（或反之）。
3. **掩盖矛盾 (Misrepresentation)**: 如果评论中对某一点存在明显分歧（有人说好，有人说坏），但摘要却只单方面说"大家都喜欢"，忽略了反面声音。
4. **格式错误**: 不符合 {style} 的格式要求。

[输出格式 - JSON]
{{
    "score": <0-10>,
    "is_factual": <boolean>,
    "format_correct": <boolean>,
    "hallucinations": [
        "摘要原句 -> 错误原因"
    ],
    "reasoning": "简短评价。"
}}
"""
    try:
        response = client.chat.completions.create(
            model=JUDGE_MODEL,
            messages=[{"role": "user", "content": judge_prompt}],
            temperature=0.0,
            response_format={"type": "json_object"}
        )
        return json.loads(response.choices[0].message.content)
    except Exception as e:
        print(f"Judge API Error: {e}")
        return {"score": 0, "is_factual": False, "format_correct": False, "hallucinations": ["API Error"], "reasoning": str(e)}

def generate_student_summary(context, style="C1"):
    if style == "A1":
        user_prompt = """Summarize these reviews for a beginner (CEFR A1).

Requirements:
- Use simple present tense, basic vocabulary.
- Write 1 paragraph of 3-4 short sentences.
- NO bullet points.
- Structure: [Overall] + [Feature] + [Conclusion].
- Reflect what most people say, but mention important issues if some people have them.

Reviews:
{context}

Output ONLY the summary.""".format(context=context)

    else:  # C1
        user_prompt = """Summarize these reviews in a professional, analytical style (CEFR C1).

Requirements:
1. **Style**: Use sophisticated vocabulary and phrasing.
2. **Format**: Use a bulleted list with EXACTLY 3-6 points total.
   - **CRITICAL**: EVERY point MUST start with `(+)`, `(-)`, or `(~)`.
   - Use `(+)` for consensus strengths.
   - Use `(-)` for consensus weaknesses.
   - Use `(~)` for mixed/controversial opinions.
   - **Order**: List all `(+)` first, then `(-)`, then `(~)`.

3. **Handling Contradictions**:
   - Report inconsistencies using phrases like "Polarized feedback...".

4. **Length**: Total summary under 180 words.

Reviews:
{context}

Output ONLY the structured summary.""".format(context=context)

    messages = [{"role": "user", "content": user_prompt}]

    inputs = tokenizer.apply_chat_template(
        messages,
        tokenize=True,
        add_generation_prompt=True,
        return_tensors="pt"
    ).to("cuda")

    outputs = model.generate(
        inputs,
        max_new_tokens=512,
        temperature=0.1,
        use_cache=True
    )

    text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    if "assistant" in text:
        return text.split("assistant")[-1].strip()
    return text

def main():
    all_test_samples = []
    print(f"\n正在从 {len(CATEGORIES)} 个品类中抽取未见验证集 (seed=42)...")

    for cat in tqdm(CATEGORIES, desc="Sampling"):
        samples = get_unseen_samples(cat, count=SAMPLES_PER_CATEGORY)
        all_test_samples.extend(samples)

    if not all_test_samples:
        print("未找到任何测试样本，请检查数据路径")
        return

    print(f"\n准备就绪，共 {len(all_test_samples)} 个样本。开始全品类真实性测试\n")

    results_a1 = []
    results_c1 = []

    GREEN = '\033[92m'
    RED = '\033[91m'
    YELLOW = '\033[93m'
    CYAN = '\033[96m'
    RESET = '\033[0m'
    BOLD = '\033[1m'

    for i, item in enumerate(all_test_samples):
        cat = item['category']
        asin = item['parent_asin']
        context = item['formatted_context']

        print(f"\n{'='*60}")
        print(f"[{i+1}/{len(all_test_samples)}] 测试产品: {cat} (ASIN: {asin})")
        print(f"{'='*60}")

        # 测试 A1 模式
        print(f"\n{CYAN}{BOLD}>>> A1 模式测试{RESET}")
        summary_a1 = generate_student_summary(context, style="A1")
        eval_a1 = evaluate_factuality(context, summary_a1, style="A1")

        res_a1 = {
            "category": cat,
            "asin": asin,
            "style": "A1",
            "summary": summary_a1,
            "score": eval_a1['score'],
            "is_factual": eval_a1['is_factual'],
            "format_correct": eval_a1.get('format_correct', True),
            "hallucinations": eval_a1['hallucinations'],
            "reasoning": eval_a1.get('reasoning', '')
        }
        results_a1.append(res_a1)

        score_a1 = eval_a1['score']
        color_a1 = GREEN if score_a1 >= 8 else (YELLOW if score_a1 >= 5 else RED)

        print(f"   生成摘要: {summary_a1[:100].replace(chr(10), ' ')}...")
        print(f"   裁判打分: {color_a1}{score_a1}/10{RESET}")
        if eval_a1['hallucinations']:
            print(f"   幻觉/错误: {RED}{eval_a1['hallucinations']}{RESET}")
        else:
            print(f"   事实核查通过")

        # 测试 C1 模式
        print(f"\n{CYAN}{BOLD}>>> C1 模式测试{RESET}")
        summary_c1 = generate_student_summary(context, style="C1")
        eval_c1 = evaluate_factuality(context, summary_c1, style="C1")

        res_c1 = {
            "category": cat,
            "asin": asin,
            "style": "C1",
            "summary": summary_c1,
            "score": eval_c1['score'],
            "is_factual": eval_c1['is_factual'],
            "format_correct": eval_c1.get('format_correct', True),
            "hallucinations": eval_c1['hallucinations'],
            "reasoning": eval_c1.get('reasoning', '')
        }
        results_c1.append(res_c1)

        score_c1 = eval_c1['score']
        color_c1 = GREEN if score_c1 >= 8 else (YELLOW if score_c1 >= 5 else RED)

        print(f"   生成摘要: {summary_c1[:100].replace(chr(10), ' ')}...")
        print(f"   裁判打分: {color_c1}{score_c1}/10{RESET}")
        if eval_c1['hallucinations']:
            print(f"   幻觉/错误: {RED}{eval_c1['hallucinations']}{RESET}")
        else:
            print(f"   事实核查通过")

        print("-" * 60)

    if not results_a1 and not results_c1: return

    # 最终统计报告
    print("\n" + "="*70)
    print("幻觉检测最终报告 (Final Factuality Report)")
    print("="*70)

    def print_stats(results, style_name):
        print(f"\n{BOLD}【{style_name} 模式统计】{RESET}")

        cat_stats = {}
        for r in results:
            c = r['category']
            if c not in cat_stats: cat_stats[c] = []
            cat_stats[c].append(r['score'])

        print(f"{'Category':<30} | {'Avg Score':<10}")
        print("-" * 45)
        for cat, scores in cat_stats.items():
            avg = sum(scores)/len(scores)
            print(f"{cat:<30} | {avg:.1f}")

        total_avg = sum(r['score'] for r in results) / len(results)
        pass_count = sum(1 for r in results if r['is_factual'])
        format_count = sum(1 for r in results if r.get('format_correct', True))
        pass_rate = (pass_count / len(results)) * 100
        format_rate = (format_count / len(results)) * 100

        print("-" * 45)
        print(f"总平均分: {total_avg:.2f} / 10")
        print(f"无幻觉通过率: {pass_rate:.1f}%")
        print(f"格式正确率: {format_rate:.1f}%")

    print_stats(results_a1, "A1")
    print_stats(results_c1, "C1")

    print("\n" + "="*70)

    # 保存结果
    all_results = {
        "A1": results_a1,
        "C1": results_c1
    }

    with open("hallucination_test_results_full.json", "w", encoding='utf-8') as f:
        json.dump(all_results, f, indent=2, ensure_ascii=False)
    print("详细结果已保存至 hallucination_test_results_full.json")

if __name__ == "__main__":
    main()
# Out:
# 正在加载微调模型: /content/drive/MyDrive/ETSP/qwen_dpo_v2...
# ==((====))==  Unsloth 2025.12.7: Fast Qwen2 patching. Transformers: 4.57.3.
#    \\   /|    NVIDIA L4. Num GPUs = 1. Max memory: 22.161 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.0+cu126. CUDA: 8.9. CUDA Toolkit: 12.6. Triton: 3.5.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.33.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Student 模型加载成功
#
# 正在从 10 个品类中抽取未见验证集 (seed=42)...
# Sampling:   0%|          | 0/10 [00:00<?, ?it/s]
# 准备就绪，共 50 个样本。开始全品类真实性测试
#
#
# ============================================================
# [1/50] 测试产品: Electronics (ASIN: B089Q5MJ2K)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the laptop because it is fast, thin, and good for work or hobbies. Many say it work...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Exceptional performance, rapid startup, lightweight design, strong value for money, and high rel...
#    裁判打分: 9/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [2/50] 测试产品: Electronics (ASIN: B0B2CX4CKD)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like this microphone because it has good sound, easy setup, and cool features like light...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: **Strengths:** - **Sound Quality:** Consistently praised for clear, crisp audio, particularly in gam...
#    裁判打分: 9/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [3/50] 测试产品: Electronics (ASIN: B084GF686M)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like these drives because they are cheap and work well for simple tasks. Some have probl...
#    裁判打分: 9/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Generally reliable for basic use, valued for cost-effectiveness and suitability for low-demand a...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [4/50] 测试产品: Electronics (ASIN: B071V4R34Z)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people say the product works well and adds memory quickly, with good speed and good service. So...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Effective performance in multiple devices, with users reporting stable functionality, improved s...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [5/50] 测试产品: Electronics (ASIN: B01IVQIG96)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like this wallet because it fits phones and cards well, looks nice, and feels good to us...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Exceptional craftsmanship and aesthetic appeal widely praised, with durable construction, premiu...
#    裁判打分: 6/10
#    幻觉/错误: ['(−) Notable durability concerns emerge, particularly regarding long-term wear and tear, with multiple users reporting rapid degradation, inconsistent build quality, and functional limitations such as oversized dimensions affecting portability. -> 摘要声称存在‘rapid degradation’和‘inconsistent build quality’属于无中生有。原文中多数用户强调产品耐用（如Review 1, 2, 5, 6, 7, 9），仅个别提及尺寸偏大或材质偏软，但无一人报告‘快速磨损’或‘质量不一致’；相反，‘wear so well’（Review 1）和‘held up great’（Review 2）表明耐久性良好。', '(~) Polarized feedback on sizing... suggesting variability in fit and suitability depending on personal preference or specific device compatibility. -> 虽然有关于尺寸的负面反馈（如Review 4, 8），但将其归纳为‘polarized feedback’（两极分化）夸大了对立程度。大多数提及尺寸的评论并未表达不满，仅少数认为偏大，而Review 12明确表示可放入后袋或夹克口袋，说明实际适配性较好；因此‘polarized’一词歪曲了数据分布，属于掩盖矛盾。']
# ------------------------------------------------------------
#
# ============================================================
# [6/50] 测试产品: Books (ASIN: 1550464051)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the book because it has nice photos of cockpits and is fun to read. Some say it is ...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Exceptional visual appeal and photographic quality widely praised, particularly for modelers and...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [7/50] 测试产品: Books (ASIN: 0765399423)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like this book because it is exciting, scary, and smart. It has cool ideas about virtual...
#    裁判打分: 9/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Exceptional narrative engagement, praised for its suspense, psychological depth, and compelling ...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [8/50] 测试产品: Books (ASIN: 1416524347)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like this book because it is scary and interesting. It has strong characters and a good ...
#    裁判打分: 8/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Exceptional narrative depth, psychological complexity, and emotional resonance in character deve...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [9/50] 测试产品: Books (ASIN: 1936880024)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like this wine tasting notebook because it helps organize thoughts and records details e...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Highly valued as a practical, user-friendly tool for wine enthusiasts, offering detailed, organi...
#    裁判打分: 8/10
#    幻觉/错误: ["(-) Perceived as poorly designed for novices or casual drinkers, lacking room for personalization or extended notes, leading to disappointment and dissatisfaction among non-professionals. -> 情感反转与掩盖矛盾：多条评论（如 Review 5, 6, 10, 13）明确指出该笔记本对初学者非常有帮助，提供了术语引导和学习支持，说明其设计实际上被广泛认为适合新手。摘要却称其'被认为不适合初学者'，这与原文正面评价相悖，构成情感反转和对共识的误传。"]
# ------------------------------------------------------------
#
# ============================================================
# [10/50] 测试产品: Books (ASIN: 0060539690)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like this book because it helps children feel excited about school and understand new ex...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Universally appreciated as a charming, engaging, and relatable book for young children, particul...
#    裁判打分: 9/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [11/50] 测试产品: Home_and_Kitchen (ASIN: B08747KPLS)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like this bathmat because it is soft, thick, and good for drying feet. It fits well in b...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Exceptional comfort, softness, and absorbency consistently praised, with users highlighting exce...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [12/50] 测试产品: Home_and_Kitchen (ASIN: B07KCSV7QW)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like these pillow covers because they are soft, nice for Christmas, and strong. They fit...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Exceptional softness, durability, and aesthetic appeal, with users praising comfort, sturdiness,...
#    裁判打分: 7/10
#    幻觉/错误: ["Accurate sizing and reliable performance in high-traffic environments, resisting pet hair and maintaining structural integrity over time. -> While durability and resistance to pet hair are supported (Review 4), 'accurate sizing' is contradicted by Review 3, which reports significant undersizing. Presenting 'accurate sizing' as a positive generalization alongside durability creates a misleading impression of consensus.", "(~) While many find them ideal, there is polarized feedback regarding size accuracy—some receive accurate fits, while others experience significant oversizing or misalignment. -> The term 'oversizing' is a hallucination; no reviewer reported a product larger than stated. Review 3 explicitly mentions the cover was smaller (18x18 vs. 20x20), not oversized. 'Misalignment' is also unmentioned in the source material."]
# ------------------------------------------------------------
#
# ============================================================
# [13/50] 测试产品: Home_and_Kitchen (ASIN: B07Y2V51PQ)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like this product because it is strong, easy to use, and helps keep bananas off counters...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Exceptional functionality and practicality for under-cabinet use, effectively addressing storage...
#    裁判打分: 9/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [14/50] 测试产品: Home_and_Kitchen (ASIN: B01NCRRHS6)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the tapestry and think it looks beautiful, feels soft, and matches well with rooms....
#    裁判打分: 6/10
#    幻觉/错误: ['Some say the colors are brighter than shown -> 评论中没有人说颜色比图片更亮，相反多人提到颜色不如预期鲜艳（如 review 3, 12, 28），这是情感反转', 'a few have problems with smell or fit -> 评论中无人提到‘fit’问题，且只有 review 25 提到无异味（正面），没有人抱怨气味问题，属于无中生有']
#
# >>> C1 模式测试
#    生成摘要: (+) Exceptional aesthetic appeal, praised for vibrant colors, soft texture, premium feel, and suitab...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [15/50] 测试产品: Home_and_Kitchen (ASIN: B09DVZ6CD2)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people think the corn sheller works okay but has problems. It throws kernels far and is cheap, ...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Effective at removing corn kernels efficiently, particularly suitable for small-scale processing...
#    裁判打分: 9/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [16/50] 测试产品: Beauty_and_Personal_Care (ASIN: B00NL84N8I)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like these hairpins because they look nice and stay in hair well. Some say they are stro...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Stylish and visually appealing, with strong aesthetic appeal and perceived value, particularly s...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [17/50] 测试产品: Beauty_and_Personal_Care (ASIN: B07FPNR2JD)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like this grooming kit because it has many useful tools and is good quality, easy to car...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Exceptional value, high utility, and broad functionality praised across multiple users, particul...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [18/50] 测试产品: Beauty_and_Personal_Care (ASIN: B0BPF5NV9X)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like this lip gloss because it is easy to use, comes in many colors, and is good for lit...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Highly valued for portability, variety, and ease of use, with multiple users appreciating the ra...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [19/50] 测试产品: Beauty_and_Personal_Care (ASIN: B07BT7KK86)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the bottle because it looks nice and works well for makeup or nail care. Some say i...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Aesthetically pleasing and functional design, appreciated for its elegance, ease of use, and sui...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [20/50] 测试产品: Beauty_and_Personal_Care (ASIN: B0BFGWDMS9)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like this gel nail polish remover because it works well and saves time. It removes gel p...
#    裁判打分: 9/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Effective and convenient for removing gel nail polish, particularly appreciated by users who fin...
#    裁判打分: 9/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [21/50] 测试产品: Clothing_Shoes_and_Jewelry (ASIN: B07H48QGY8)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the jacket and think it looks nice and fits well for many. It is often too small, w...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Stylish, high-quality material, versatile design, and strong value proposition, particularly app...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [22/50] 测试产品: Clothing_Shoes_and_Jewelry (ASIN: B07BHWGSPF)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the shirt and think it looks good and feels comfortable. Some say it fits well and ...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Well-received for its design, comfort, and motivational appeal, particularly among fans of super...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [23/50] 测试产品: Clothing_Shoes_and_Jewelry (ASIN: B002HIDE60)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like these gem jars because they are strong, stack well, and protect small items well. T...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Strong, durable construction widely praised for secure storage, effective protection against sma...
#    裁判打分: 9/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [24/50] 测试产品: Clothing_Shoes_and_Jewelry (ASIN: B08HLR1PKZ)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like this sweater because it is warm, comfy, and fits well. It looks nice and many say i...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Well-liked for its comfort, flattering fit, and practical features such as pockets and vented si...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [25/50] 测试产品: Clothing_Shoes_and_Jewelry (ASIN: B0BM3H5T48)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like this costume because it looks good, fits well, and is fun for Easter or parties. It...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Well-made, comfortable, and versatile costume with strong durability, suitable for multiple occa...
#    裁判打分: 8/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [26/50] 测试产品: Toys_and_Games (ASIN: B07RB7YVD3)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the ball pit because kids enjoy playing with it and it is fun for young children. S...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Valued as a fun, engaging toy for toddlers and infants, particularly appreciated for aesthetic a...
#    裁判打分: 6/10
#    幻觉/错误: ['(+) Generally seen as a good value for money for its intended age group, suitable for 2-3 year olds -> 情感反转与掩盖矛盾：多条评论（如 Review 2、4、6、9）明确指出产品不值 $40，质量差，且不适合 2.5 岁以上儿童；摘要称‘普遍认为物有所值’并‘适合 2-3 岁’与原文负面评价冲突，构成情感反转和选择性归纳。', '(+) ...suitable for 2-3 year olds -> 无中生有与掩盖矛盾：Review 2 明确指出‘definitely not for children over 2.5 years old’，Review 8 认为 2 岁以上就太小，而摘要声称适合 2-3 岁，直接 contradicts 原文核心批评点。']
# ------------------------------------------------------------
#
# ============================================================
# [27/50] 测试产品: Toys_and_Games (ASIN: B074LYTYM8)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the art and size of the game mat. It is good quality, big, and many find it cute or...
#    裁判打分: 8/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) High-quality construction and aesthetic appeal widely praised, with strong satisfaction for desi...
#    裁判打分: 6/10
#    幻觉/错误: ["High-quality construction and aesthetic appeal widely praised, with strong satisfaction for design, durability, and visual appeal, particularly in thematic accuracy and craftsmanship. -> 'Thematic accuracy' and 'craftsmanship' are not explicitly mentioned or inferable from the reviews; 'durability' is never discussed.", "Polarized feedback on perceived quality: while some highlight excellent build and resolution, others dismiss it as merely 'good' or 'okay,' indicating inconsistent expectations or standards. -> There is no polarization in the feedback; all reviews are positive or neutral without any negative sentiment. The claim of polarization misrepresents the consensus."]
# ------------------------------------------------------------
#
# ============================================================
# [28/50] 测试产品: Toys_and_Games (ASIN: B0915NYV5W)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like this tablet because it is simple, fun, and easy to use for young children. It helps...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Lightweight, user-friendly design widely appreciated for simplicity, ease of use, and portable c...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [29/50] 测试产品: Toys_and_Games (ASIN: B09FFVJFWL)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people say the battery works well and fits some small cars like the Mini-B or UTB18. But many h...
#    裁判打分: 8/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Effective performance and functional compatibility when used as intended, particularly for testi...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [30/50] 测试产品: Toys_and_Games (ASIN: B00UAGJTI8)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: These small zombie figures are good for board games and fun. They glow in the dark and fit well in b...
#    裁判打分: 8/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Highly valued as a cost-effective alternative to cardboard cutouts, offering vibrant glow-in-the...
#    裁判打分: 6/10
#    幻觉/错误: ['(-) Criticized for being significantly smaller than expected, limiting visibility and immersion, especially for experienced players accustomed to larger figures. -> 评论中无人批评尺寸‘小于预期’或指出其‘限制沉浸感’；相反，提及尺寸者多持中性或正面态度（如更易收纳、适合游戏需求），且无证据表明‘经验丰富的玩家’普遍认为其过小。', '(~) Polarized feedback on size: while some find them ideal for compact scenarios or children’s play, others view them as inadequate for adult gaming needs or traditional board games. -> 原文中不存在将尺寸与‘成人游戏需求’或‘传统桌游适用性’对立的评价；也无任何评论认为其‘不适用于成人游戏’，此为无依据推断。']
# ------------------------------------------------------------
#
# ============================================================
# [31/50] 测试产品: Sports_and_Outdoors (ASIN: B00N2BWHWS)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the Fitbit Surge for fitness tracking, especially heart rate and sleep. It works we...
#    裁判打分: 8/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Strong user satisfaction for basic fitness tracking, particularly step counting, sleep monitorin...
#    裁判打分: 9/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [32/50] 测试产品: Sports_and_Outdoors (ASIN: B009YMGP4K)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like this griptape because it grips well and lasts a long time. It is strong and works g...
#    裁判打分: 6/10
#    幻觉/错误: ['but some say it wears down fast -> 评论中多人提到 griptape 持久、grips well 且 lasting，无人说它 wear down fast', "or comes with problems like bad smell or wrinkles -> 评论中未提及 bad smell；wrinkles 未出现，最接近的是 'crease' 和 'air bubble'，但不能等同为 wrinkles"]
#
# >>> C1 模式测试
#    生成摘要: (+) Exceptional grip performance, durability, and customer satisfaction across multiple users, parti...
#    裁判打分: 6/10
#    幻觉/错误: ['(-) Worn down quickly and excessive wear observed, particularly on high-frequency users or those with aggressive riding styles, indicating suboptimal durability compared to expectations. -> 情感反转与无中生有：原文中多条评论（如 Review 4, 5, 6, 12–14）明确称赞其耐用性，且未提及‘高频率使用者或激进滑行导致快速磨损’；相反，Review 8 指出‘抓地力太强导致新鞋三小时内磨穿’，属于过度性能而非劣质，摘要误将此归因为‘耐久性差’，构成对用户反馈的错误解读。']
# ------------------------------------------------------------
#
# ============================================================
# [33/50] 测试产品: Sports_and_Outdoors (ASIN: B0964BRXBY)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the webbing because it is strong, easy to see, and good for many uses like straps o...
#    裁判打分: 9/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) High durability and practical utility across multiple applications, including sail ties, pet acc...
#    裁判打分: 9/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [34/50] 测试产品: Sports_and_Outdoors (ASIN: B08D3MWRX1)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people think the cables are good and work well for many bikes. They are cheap, easy to use, and...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) High value for money, widely praised for affordability, ease of installation, and suitability fo...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [35/50] 测试产品: Sports_and_Outdoors (ASIN: B07H9SS7W8)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the counters and think they work well for counting people. Some say they are good a...
#    裁判打分: 5/10
#    幻觉/错误: ['Most people like the counters and think they work well for counting people. -> 情感反转和掩盖矛盾：评论中多数反馈是负面的，四个评论中有两个明确表示所有或多个设备迅速损坏，且质疑准确性；只有两个简短正面评价，摘要却称‘大多数人喜欢’，严重歪曲整体情绪。']
#
# >>> C1 模式测试
#    生成摘要: (+) Valued for basic counting needs, particularly in crowded settings like bars or festivals, offeri...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [36/50] 测试产品: Pet_Supplies (ASIN: B09VD3CC62)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like these liners because they are soft, comfortable, and good for pets or small animals...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Well-regarded for comfort, softness, and practicality in pet carriers, with multiple users prais...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [37/50] 测试产品: Pet_Supplies (ASIN: B08VW2Z69W)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like these perches because they are strong, easy to use, and good value. They work well ...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Durable and well-regarded for small birds, offering strong structural integrity, ease of use, an...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [38/50] 测试产品: Pet_Supplies (ASIN: B07VVNYZVY)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the sand because it looks good and works well for projects like vases, displays, or...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) High value for money, widely appreciated for practical uses such as weight support, decorative f...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [39/50] 测试产品: Pet_Supplies (ASIN: B09FJJ568T)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the dog sweaters because they look cute and keep dogs warm in winter. They work wel...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Adored for its cuteness and warmth, particularly appreciated in cold weather, with multiple user...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [40/50] 测试产品: Pet_Supplies (ASIN: B09QJN2K78)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like this dog food because it is high quality, healthy, and good for pets. Many dogs lov...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) High-quality, nutritious ingredients widely praised for promoting healthy skin, coat, and digest...
#    裁判打分: 9/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [41/50] 测试产品: Automotive (ASIN: B08X1XR4RG)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the product and say it works well for fixing problems like squeaks and play in the ...
#    裁判打分: 9/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Well-received for effective performance in restoring smoothness and eliminating play, particular...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [42/50] 测试产品: Automotive (ASIN: B07QZV17GV)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the filter because it looks good and feels strong. Some say it fits well at first b...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Generally perceived as a cost-effective alternative with functional components, offering accepta...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [43/50] 测试产品: Automotive (ASIN: B074138CV1)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people think the seat is good and fits well. It is a good value and works well for many bikes, ...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) High-quality, accurate fit and reliable performance across multiple models, with strong satisfac...
#    裁判打分: 9/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [44/50] 测试产品: Automotive (ASIN: B01NH0A4H6)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the seat covers because they look nice and fit well in some cars. Some say the fabr...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Visually appealing and aesthetically pleasing, with several users appreciating design, color, an...
#    裁判打分: 9/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [45/50] 测试产品: Automotive (ASIN: B018QF1URC)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the pants because they are soft, comfortable, and look good. Some say they are too ...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) High-quality construction, comfortable fit, and appealing design are consistently praised, with ...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [46/50] 测试产品: Office_Products (ASIN: B09J4LZ8TM)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like this tape dispenser because it is easy to use, cuts tape quickly, and saves time. S...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Highly valued as a functional, user-friendly solution for heat-resistant tape applications, prai...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [47/50] 测试产品: Office_Products (ASIN: B07WDGJVT3)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people say the toner works well and fits their printers easily. It prints good quality and many...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Effective performance and user-friendly installation, with multiple users reporting flawless fun...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [48/50] 测试产品: Office_Products (ASIN: B00K6EFN3O)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like these boxes because they are strong, easy to use, and good for shipping dolls or sm...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Exceptional value and utility for doll and small item shipping, praised for sturdiness, ease of ...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [49/50] 测试产品: Office_Products (ASIN: B096M3ZXS5)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the board because it looks nice, is cute, and useful for organizing or hanging deco...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Stylish, visually appealing design with strong aesthetic appeal, particularly appreciated in hom...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ============================================================
# [50/50] 测试产品: Office_Products (ASIN: B07GTXYJWC)
# ============================================================
#
# >>> A1 模式测试
#    生成摘要: Most people like the product and think it looks nice. It arrives fast, feels good, and many are happ...
#    裁判打分: 10/10
#    事实核查通过
#
# >>> C1 模式测试
#    生成摘要: (+) Exceptional aesthetic appeal, high-quality craftsmanship, and strong customer satisfaction with ...
#    裁判打分: 10/10
#    事实核查通过
# ------------------------------------------------------------
#
# ======================================================================
# 幻觉检测最终报告 (Final Factuality Report)
# ======================================================================
#
# 【A1 模式统计】
# Category                       | Avg Score
# ---------------------------------------------
# Electronics                    | 9.8
# Books                          | 9.4
# Home_and_Kitchen               | 9.2
# Beauty_and_Personal_Care       | 9.8
# Clothing_Shoes_and_Jewelry     | 10.0
# Toys_and_Games                 | 8.8
# Sports_and_Outdoors            | 7.6
# Pet_Supplies                   | 10.0
# Automotive                     | 9.8
# Office_Products                | 10.0
# ---------------------------------------------
# 总平均分: 9.44 / 10
# 无幻觉通过率: 94.0%
# 格式正确率: 100.0%
#
# 【C1 模式统计】
# Category                       | Avg Score
# ---------------------------------------------
# Electronics                    | 8.8
# Books                          | 9.4
# Home_and_Kitchen               | 9.0
# Beauty_and_Personal_Care       | 9.8
# Clothing_Shoes_and_Jewelry     | 9.4
# Toys_and_Games                 | 7.6
# Sports_and_Outdoors            | 8.8
# Pet_Supplies                   | 9.8
# Automotive                     | 9.6
# Office_Products                | 10.0
# ---------------------------------------------
# 总平均分: 9.22 / 10
# 无幻觉通过率: 86.0%
# 格式正确率: 100.0%
#
# ======================================================================
# 详细结果已保存至 hallucination_test_results_full.json
